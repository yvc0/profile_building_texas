# %%
# string - string is collection of charecters or group of charecters enclosed by ' ' or " "
name = "venkatesh yekkanti"
print(type(name))
print(name)
# Out:
# <class 'str'>
# venkatesh yekkanti

# %%
name1 = "venkatesh"
name2 = "aniket"
name3 = 'sonam'
name4 = 'indu'
name5 = '''
tanjeela
divya
sonam
indu
'''
print(type(name1))
print(type(name2))
print(type(name3))
print(type(name4))
print(type(name5))
print(name1)
print(name2)
print(name3)
print(name4)
print(name5)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# venkatesh
# aniket
# sonam
# indu
#
# tanjeela
# divya
# sonam
# indu

# %%
# string concatenation - adding mutliple string 
name1 = "indu"
name2 = "sonam"
name3 = 'bhavya'
name4 = 'tanjeela'
print(name1+' '+name2)
print(name1+' '+name2+' '+name3)
print(name1+' '+name2+' '+name3+' '+name4)
# Out:
# indu sonam
# indu sonam bhavya
# indu sonam bhavya tanjeela

# %%
num1 = '10'
num2 = '20'
print(num1+num2)
# Out:
# 1020

# %%
# charecters accessing - 
# forward index - start from 0 to n-1(it start from left to right)
# backward or negitive index - -1 to -n(it start from right to left)
# accessing charecters using squre brackets
example1 = 'python programming workshop'
print(example1[-9])

# %%
# i need to get group of charecetrs
# slicing conecpt to get group of charecetrs
# [start:end-1:step(optional)] - define as slicing of string
example1 = 'python programming workshop'
print(example1[-3:]) # [0:5-1]
# Out:
# hop

# %%
# i need to get group of charecetrs
# slicing conecpt to get group of charecetrs
# [start:end-1:step(optional)] - define as slicing of string
example1 = 'python programming workshop'
print(example1[4:]) # [0:5-1]
# Out:
# on programming workshop

# %%
# i need to get group of charecetrs
# slicing conecpt to get group of charecetrs
# [start:end-1:step(optional)] - define as slicing of string
example1 = 'python programming workshop'
print(example1[:10]) # [0:5-1] # [start:end(exclusive)]
# Out:
# python pro

# %%
example1 = 'python programming workshop'
print(example1[4:]) # ending index takes last index value in the string
# Out:
# on programming workshop

# %%
example1 = 'python programming workshop'
print(example1[:12]) # starting index position default takes 0
# Out:
# python progr

# %%
example1 = 'python programming workshop'
print(example1[0:12]) # starting index position default takes 0
# Out:
# python progr

# %%
# [start:end:step]
example1 = 'python programming workshop'
print(example1[:])
# Out:
# python programming workshop

# %%
# [start:end:step]
example1 = 'python programming workshop'
print(example1[::])
# Out:
# python programming workshop

# %%
# [start:end:step]
example1 = 'python programming workshop'
print(example1[0:10:4]) # in this case edning index postion
# Out:
# por

# %%
# i need to print even index position charecters from string
example1 = 'python programming workshop'
print(example1[0::2])
# Out:
# pto rgamn okhp

# %%
# i need to print even index position charecters from string
example1 = 'python programming workshop'
print(example1[1::2])
# Out:
# yhnpormigwrso

# %%
example1 = 'python programming workshop'
c = 0
for i in example1:
    print(i,end='')
# Out:
# python programming workshop

# %%
2%2
# Out:
# 0

# %%
# i need to print even index position charecters from string
example1 = 'python programming workshop'
c = 0
for i in example1:
    if (c%2!=0):
        print(i,end='')
    c = c + 1
# Out:
# yhnpormigwrso

# %%
# i need to print odd index position charecters from string
