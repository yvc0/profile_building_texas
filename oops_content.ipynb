# %% [markdown]
# #### Python Object Oriented Programming
# 1. class
# 2. object
# 3. method
# 4. Constructor
# 5. inheritance
# 6. data encapsulation and data abstraction
# 7. polymorphism
#
# ##### Class
# - class is the blueprint of the object. it contains statements, methods or functions constructors
# - we can create the class using class keyword
# - synatx
#     - ```python
#     class ClassName:
#         constructors..
#         statements..
#         functions..(def functions_name()...)
#     ```
#
# ##### Object
# - object is used to access the class functionalities or class attributes
# - ```python object syntax
# class ClassName:
#     hjsdjs
#     kjhshdks
#     khnjdksj
#     def data(sjhdshg):
#         return some datao
# object1 = ClassName()
#     ```
#
# ##### method
# - method is collection statements
# - ```syntx
# class Data:
#     def my_profile(self,name,age,salary):
#         print(age)
#         ......
#
# object1 = Data()
# object1.my_profile()
#     ```
#
# ##### Constructor
# - simple defination of constructor is passing the arguments with in the class defining in constructor
# - ```syntax
# class MyData:
#     def __init__(self,name,age,salary,address,contact):
#         self.name=name
#         self.age=age
#         self.salary=salary
#         .......
#     ```
# ##### Inheritance
# - acquring properties from parent class to child class and add some more feature to child class
# - inheritance is the process of derived the properties of one class to another class
#     - derived class -----> base class
#     1. single inheritance
#     2. multiple inheritance
#     3. multilevel inheritance
#     4. hirachy inheritance
#
# ###### data abstraction and data encapsulation
# - data protecting purpose we can use data abstarction and data encapsulation
#     1. public data(we can access everyone that means outside the class also its using)
#     2. private data(these type of data accessed by class memebrs only. and outside class it's npt working because it's a private data)
#
#
# ###### Polymorphism
# - polymorphism is many problemes executed in same patterns
