# %%
# read data from dataframes by using 
# 1. loc
# 2. iloc

# %%
import pandas as pd
df = {'student names':['sonam','bhavya','tanzeela','aniket','joseph','indu','venkat','divya'],
     'branches':['physics','chemistry','maths','physics','maths','chemistry','ece','arts'],
     'percentage':[40,50,30,20,90,50,78,89],
     'placement':['wipro','infosys','tcs','bosch','bose','ford','tcs','wipro'],
     'location':['hyd','mumbai','del','chennai','kolkata','pune','del','pune'],
     'salary':[50000,30000,40000,50000,35000,56000,23000,45000]}
data1 = pd.DataFrame(df)
data1
# Out:
#   student names   branches  percentage placement location  salary
# 0         sonam    physics          40     wipro      hyd   50000
# 1        bhavya  chemistry          50   infosys   mumbai   30000
# 2      tanzeela      maths          30       tcs      del   40000
# 3        aniket    physics          20     bosch  chennai   50000
# 4        joseph      maths          90      bose  kolkata   35000
# 5          indu  chemistry          50      ford     pune   56000
# 6        venkat        ece          78       tcs      del   23000
# 7         divya       arts          89     wipro     pune   45000

# %%
import pandas as pd
df = {'student names':['sonam','bhavya','tanzeela','aniket','joseph','indu','venkat','divya'],
     'branches':['physics','chemistry','maths','physics','maths','chemistry','ece','arts'],
     'percentage':[40,50,30,20,90,50,78,89],
     'placement':['wipro','infosys','tcs','bosch','bose','ford','tcs','wipro'],
     'location':['hyd','mumbai','del','chennai','kolkata','pune','del','pune'],
     'salary':[50000,30000,40000,50000,35000,56000,23000,45000]}
data2 = pd.DataFrame(df,index=['rc1','rc2','rc3','rc4','rc5','rc6','rc7','rc8'])
data2
# Out:
#     student names   branches  percentage placement location  salary
# rc1         sonam    physics          40     wipro      hyd   50000
# rc2        bhavya  chemistry          50   infosys   mumbai   30000
# rc3      tanzeela      maths          30       tcs      del   40000
# rc4        aniket    physics          20     bosch  chennai   50000
# rc5        joseph      maths          90      bose  kolkata   35000
# rc6          indu  chemistry          50      ford     pune   56000
# rc7        venkat        ece          78       tcs      del   23000
# rc8         divya       arts          89     wipro     pune   45000

# %%
data1
# Out:
#   student names   branches  percentage placement location  salary
# 0         sonam    physics          40     wipro      hyd   50000
# 1        bhavya  chemistry          50   infosys   mumbai   30000
# 2      tanzeela      maths          30       tcs      del   40000
# 3        aniket    physics          20     bosch  chennai   50000
# 4        joseph      maths          90      bose  kolkata   35000
# 5          indu  chemistry          50      ford     pune   56000
# 6        venkat        ece          78       tcs      del   23000
# 7         divya       arts          89     wipro     pune   45000

# %%
data1.iloc[[0,2,4,7]]
# Out:
#   student names branches  percentage placement location  salary
# 0         sonam  physics          40     wipro      hyd   50000
# 2      tanzeela    maths          30       tcs      del   40000
# 4        joseph    maths          90      bose  kolkata   35000
# 7         divya     arts          89     wipro     pune   45000

# %%
data2
# Out:
#     student names   branches  percentage placement location  salary
# rc1         sonam    physics          40     wipro      hyd   50000
# rc2        bhavya  chemistry          50   infosys   mumbai   30000
# rc3      tanzeela      maths          30       tcs      del   40000
# rc4        aniket    physics          20     bosch  chennai   50000
# rc5        joseph      maths          90      bose  kolkata   35000
# rc6          indu  chemistry          50      ford     pune   56000
# rc7        venkat        ece          78       tcs      del   23000
# rc8         divya       arts          89     wipro     pune   45000

# %%
data1.iloc[2]
# Out:
# student names    tanzeela
# branches            maths
# percentage             30
# placement             tcs
# location              del
# salary              40000
# Name: 2, dtype: object

# %%
data2.iloc[2]
# iloc default index values it's consider
# Out:
# student names    tanzeela
# branches            maths
# percentage             30
# placement             tcs
# location              del
# salary              40000
# Name: rc3, dtype: object

# %%
data1.loc[0]
# Out:
# student names      sonam
# branches         physics
# percentage            40
# placement          wipro
# location             hyd
# salary             50000
# Name: 0, dtype: object

# %%
data2.loc['rc5']
# Out:
# student names     joseph
# branches           maths
# percentage            90
# placement           bose
# location         kolkata
# salary             35000
# Name: rc5, dtype: object

# %%
# I want read multiple records at a time
data1.iloc[0:4]
# Out:
#   student names   branches  percentage placement location  salary
# 0         sonam    physics          40     wipro      hyd   50000
# 1        bhavya  chemistry          50   infosys   mumbai   30000
# 2      tanzeela      maths          30       tcs      del   40000
# 3        aniket    physics          20     bosch  chennai   50000

# %%
data1.loc[0:4]
# Out:
#   student names   branches  percentage placement location  salary
# 0         sonam    physics          40     wipro      hyd   50000
# 1        bhavya  chemistry          50   infosys   mumbai   30000
# 2      tanzeela      maths          30       tcs      del   40000
# 3        aniket    physics          20     bosch  chennai   50000
# 4        joseph      maths          90      bose  kolkata   35000

# %%
data2.loc['rc1':'rc4']
# Out:
#     student names   branches  percentage placement location  salary
# rc1         sonam    physics          40     wipro      hyd   50000
# rc2        bhavya  chemistry          50   infosys   mumbai   30000
# rc3      tanzeela      maths          30       tcs      del   40000
# rc4        aniket    physics          20     bosch  chennai   50000

# %%
data2.iloc[0:4]
# Out:
#     student names   branches  percentage placement location  salary
# rc1         sonam    physics          40     wipro      hyd   50000
# rc2        bhavya  chemistry          50   infosys   mumbai   30000
# rc3      tanzeela      maths          30       tcs      del   40000
# rc4        aniket    physics          20     bosch  chennai   50000

# %%
# how can we filter the data
data1
# Out:
#   student names   branches  percentage placement location  salary
# 0         sonam    physics          40     wipro      hyd   50000
# 1        bhavya  chemistry          50   infosys   mumbai   30000
# 2      tanzeela      maths          30       tcs      del   40000
# 3        aniket    physics          20     bosch  chennai   50000
# 4        joseph      maths          90      bose  kolkata   35000
# 5          indu  chemistry          50      ford     pune   56000
# 6        venkat        ece          78       tcs      del   23000
# 7         divya       arts          89     wipro     pune   45000

# %%
output1 = data1[data1['salary']>40000]
output1[output1['location']=='pune']
# Out:
#   student names   branches  percentage placement location  salary
# 5          indu  chemistry          50      ford     pune   56000
# 7         divya       arts          89     wipro     pune   45000

# %%
data1[data1[data1['salary']>40000]['location']=='pune']
# Out:
# C:\Users\yvenk\AppData\Local\Temp\ipykernel_4740\4107690951.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data1[data1[data1['salary']>40000]['location']=='pune']
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4740\4107690951.py in <module>
# ----> 1 data1[data1[data1['salary']>40000]['location']=='pune']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3494         # Do we have a (boolean) 1d indexer?
#    3495         if com.is_bool_indexer(key):
# -> 3496             return self._getitem_bool_array(key)
#    3497
#    3498         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
# ...
