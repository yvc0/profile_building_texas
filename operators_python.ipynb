# %% [markdown]
# ### operators in python
# 1. Arithematic operators
#     1. +,-,*,/,//,**,%
# 2. Assignment Operators
#     1. +=,-=,/=,//=,**=..
# 3. comparision operators
#     1. >,<,<=,>=,==,!=
# 4. logical opearators
#     1. and,or,not
# 5. identity operators
#     1. is , is not
# 6. membership operators
#     1. in , not in

# %%
a = 12
b = 13
c = 14
d = 243
e = 12.3
print(a+b)
print(b-d)
print(a+b-c*d) # pedmas
print(a**b)
print(a/b) # division return float values
print(a//b) # floor division return integer values
# Out:
# 25
# -230
# -3377
# 106993205379072
# 0.9230769230769231
# 0

# %%
12+13-14*243
# Out:
# -3377

# %%
# a having 5 b having 2 and applying division result will be integer?
5//2
# Out:
# 2

# %%
# assignment operators is arithematic operators folowed by =
a = 10
a**=2
print(a)
# Out:
# 100

# %%
# comparision operators - this opeartors used comparing multiple variables
# <,>,<=,>=,==,!= these opearotrs returns True or False
a = 10
b = 10
print(a!=b) # 10 != 10
# Out:
# False

# %%
a = True
b = True
a and b # and operator both conditions are true then result is true
# Out:
# True

# %%
name1 = "abc"
name2 = "abc"
name1=="abcd" or  name2=="abcde" # True or False # one condition is true then result is true
# Out:
# False

# %%
# is and is not identity operators return true or fasle
a = 10
a is not 12
# Out:
# <>:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# C:\Users\yvenk\AppData\Local\Temp\ipykernel_7732\3498802523.py:3: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   a is not 12
# True

# %%
name ="abcd"
name is "abc"
# Out:
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\yvenk\AppData\Local\Temp\ipykernel_7732\1741522112.py:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   name is "abc"
# False

# %%
# membership operators in and not in
class1 = ['abcd','abc','edf','ghj']
'abcd' not in class1
# Out:
# False
